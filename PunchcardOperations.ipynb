# %% [markdown]
# # Punch Card Operations
#
# Stéfan Sinclair &amp; Geoffry Rockwell
#
# We're exploring here some of the operations and algorithms used by early computing humanists, including Father Roberto Busa. For this experiment we're considering in particular IBM engineer Paul Tasman's description "[Literary Data Processing](http://ieeexplore.ieee.org/document/5392686/?reload=true&arnumber=5392686)."

# %% [markdown]
# ## Data Entry of Phrases
#
# *The Automatic Punch, controlled by a keyboard similar to that of an ordinary typewriter, «wrote» by holes or perforations, one for each card, all the lines; a total of 136 cards. This is the sole work done by human eyes and fingers directly and responsibly; if at this point oversights occur, the error will be repeated from stage to stage; but if no mistakes were made, or were eliminated, there is no fear of fresh errors; human work from now onwards is reduced to mere supervision on the proper functioning of the various machines.*
#
# For the purposes of this replication we won't bother initially with the mechanics of a punchcard, we'll simply create an array of 136 strings which we'll then endeavour to treat as if they were punch cards.
#
# Rather than use a local data file for the Dante's *Divine Comedy*, we'll read from a [plain text URL](https://www.clear.rice.edu/comp200/resources/texts/Dante%20Divine%20Comedy.txt) (and assume that it will remain available), and then extract Canto III.

# %%
import urllib.request

# grab the entire Divine Comedy
inferno_url = 'https://raw.githubusercontent.com/zioproto/hadoop-swift-tutorial/master/dcu.txt'
with urllib.request.urlopen(inferno_url) as response:
   inferno_text = response.read().decode()

# %%
import re

# extract Canto III
canto3 = inferno_text[inferno_text.find("Inferno: Canto III") : inferno_text.find("Inferno: Canto IV")].strip()

# split the string into lines (removing the title line)
cards = re.split('\n+', canto3)[1:]
print("We have ", len(cards), '"cards" (or lines).')
# Out:
# We have  136 "cards" (or lines).

# %% [markdown]
# ## Checking the Data Entry
#
# *The collator can also be used to verify and correct the cards which have been manually punched at the beginning, and thus guarantee the accuracy of the transcription, an indispensable condition for philological works, particularly in the light of their peculiar function. Two separate typists punch the same text, each on his own; the collator compares the two series of cards, perceiving the discrepancies; of the cards not coinciding, at least one is wrong. This control allows only the following case to pass unobserved, namely two typists make the same error in the same place. This case is very improbable and so much the less probable in as much as the qualities and circumstances of typing and typist are different.*
#
# We don't need to check transcription, although there could be some discussion about possible typos and editorial decisions in this edition.
#
# ## Another Way of Checking
#
# *This method of verifying, although substantially the same, offers perhaps some advantages over the other, usually employed by IBM in the intent of not doubling the number, and consequently the cost, of the cards purposely, whereas in our case this is no hindrance, since each card already has to be multiplied as many times as the words it contains; the punched cards are put through the Verifier on the keys of which a typist repeats the sane text; the machine signals him when his punching does not concord with the existing holes; one of the two is wrong.*
#
# Again, this doesn't seem especially relevant.
#
# ## Transcribing
#
# *The contents of each card can be made legible either on the punch itself which, if required, can simultaneously write in letters on the upper edge of the card what is «written» in holes on the various lines of columns thereon; or else on a second machine, the so-called Interpreter, which transcribes in letters the holes it encounters on the cards (previously punched). This offers not only a more accurate transcription in virtue of the better type and greater spacing of the characters, but a transcription which can be effected on any desired portion of the card.*
#
# For now, since we're not reproducing the punch card object visually, this can be skipped.
#
# ## Tokenization
#
# *The 136 cards thus punched were then processed through a third machine, the Reproducer: this automatically copied them on another 136 cards, but adding, sideways of the lines and their quotations, the first of the words contained in each. Subsequently it makes a second copy, adding on the side the second word, then a third copy adding the third, and so forth. There were finally 943 cards, as many as were the words of the third canto of Dante's Inferno; thus each word in that canto had its card, accompanied by the text (or rather, here, by the line) and by the quotation.*
#
# *This is equivalent to state that each line was multiplied as many times as words it contained. I must confess that in actual practice this was not so simple as I endeavoured to make it in the description; the second and the successive words did not actually commence in the same column on all cards. In fact, it was this lack of determined fields which constituted the greatest hindrance in transposing the system from the commercial and statistical uses to the sorting of words from a literary text. The result was attained by exploring the cards, column by column, in order to identify by the non-punched columns the end of the previous word and the commencement of the following one; thus, operating with the sorter and reproducer together, were produced only those words commencing and finishing in the same columns.*
#
# So, before we begin this, an important step is needed to transform the text from each card into something more plausible. At the moment each line has been transcribed faithfully, but that's not what happened (even if it's not described). In particular, we need at least the following operations:
#
# * convert words to uppercase
# * filter out anything that's not part of a word (quotes, punctuation, based on the total number of cards, hyphens and apostrophes internal to words – like *l’etterno* – were also stripped)
# * strip out accented characters
# * normalize spacing (no leading or trailing spaces, single space between words)
#
# Presumably these operations would have been performed during the initial data entry, but we'll do it now since it wasn't made clear earlier.

# %%
import unicodedata

# convert to upper case
clean_cards = [line.upper() for line in cards]

# keep word characters only
clean_cards = [" ".join(re.findall(r'\b\w+\b', line.strip())) for line in clean_cards]

# remove accents
clean_cards = [unicodedata.normalize('NFKD', line).encode("ascii", 'ignore').decode() for line in clean_cards]
clean_cards[0:10]
# Out:
# ['PER ME SI VA NE LA CITTA DOLENTE',
#  'PER ME SI VA NE L ETTERNO DOLORE',
#  'PER ME SI VA TRA LA PERDUTA GENTE',
#  'GIUSTIZIA MOSSE IL MIO ALTO FATTORE',
#  'FECEMI LA DIVINA PODESTATE',
#  'LA SOMMA SAPIENZA E L PRIMO AMORE',
#  'DINANZI A ME NON FUOR COSE CREATE',
#  'SE NON ETTERNE E IO ETTERNO DURO',
#  'LASCIATE OGNE SPERANZA VOI CH INTRATE',
#  'QUESTE PAROLE DI COLORE OSCURO']

# %% [markdown]
# The next step is to tokenize. The algorighm described above by Tasman may not seem especially efficient, but it does have the merit of being algorithmically simple: you consider every column where a word starts (the first column or any column preceded by a space (or no punches), then one column at a time, you look for cards where words end.

# %%
wordcards = [] # our new stack of cards with each word

# look for columns with a space (starting with -1, or before the first word)
for start_column in range(-1, 50):
    
    # make a temporary stack of cards for words that start in this column
    start_cards = [card for card in clean_cards
                   if len(card)>start_column and (start_column==-1 or card[start_column]==" ")]
    
    # now look at each column after the start column (skip the first letter)
    for end_column in range(start_column+1, 50):
        
        # look at each remaining card
        for index, card in enumerate(list(start_cards)):
            
            # if the end column is a space or if it's the last character in the line
            if len(card) >= end_column and (len(card)==end_column or card[end_column]==" "):
                
                # add it to our word cards and remove it from our temporary stack
                wordcards.append((index, start_column+1, end_column, card[start_column+1:end_column], card))
                start_cards.remove(card)

wordcards[0:5]
# Out:
# [(17, 0, 1, 'C', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  (18, 0, 1, 'E', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (30, 0, 1, 'E', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (32, 0, 1, 'E', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (42, 0, 1, 'E', 'E IO MAESTRO CHE E TANTO GREVE')]

# %%
len(wordcards)
# Out:
# 956

# %% [markdown]
# **GR**: Tasman talks about 943 cards, one per word, but try as I might I can't see how he gets to that number... Also, I'm not sure how to deal with diacritics, you?

# %% [markdown]
# ## Sorting
#
# *Having reached this point, it is a trifle to put the words into alphabetical order; the Sorter, proceeding backwards, from the last letter, sorts and groups gradually column by column, all the identical letters; in a few minutes the words are aligned and the card file, in alphabetical order, is already compiled.*

# %%
# we'll do this properly as per the description, but here's a simpler version
sorted(wordcards, key=lambda tup: tup[3])
# Out:
# [(43, 0, 1, 'A', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  (62, 0, 1, 'A', 'A DIO SPIACENTI E A NEMICI SUI'),
#  (15, 5, 6, 'A', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  (24, 7, 8, 'A', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  (0, 8, 9, 'A', 'DINANZI A ME NON FUOR COSE CREATE'),
#  (1, 8, 9, 'A', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  (7, 8, 9, 'A', 'ED ELLI A ME QUESTO MISERO MODO'),
#  (9, 8, 9, 'A', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  (11, 9, 10, 'A', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  (8, 11, 12, 'A', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  (15, 11, 12, 'A', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  (6, 14, 15, 'A', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  (12, 14, 15, 'A', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  (16, 14, 15, 'A', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  (3, 15, 16, 'A', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  (7, 15, 16, 'A', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  (24, 16, 17, 'A', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  (10, 18, 19, 'A', 'A DIO SPIACENTI E A NEMICI SUI'),
#  (21, 20, 21, 'A', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  (2, 22, 23, 'A', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (16, 25, 26, 'A', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  (0, 5, 15, 'ACCENNANDO', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  (1, 17, 24, 'ACCENTI', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  (0, 26, 33, 'ACCORTA', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  (0, 23, 32, 'ACHERONTE', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  (16, 22, 24, 'AD', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  (12, 29, 31, 'AD', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  (6, 27, 33, 'ADAGIA', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  (14, 26, 31, 'ADAMO', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  (0, 16, 20, 'AERE', 'RISONAVAN PER L AERE SANZA STELLE'),
#  (1, 30, 36, 'AGGIRA', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  (83, 0, 2, 'AL', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  (21, 7, 9, 'AL', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  (11, 10, 12, 'AL', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  (0, 15, 17, 'AL', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  (2, 16, 18, 'AL', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (6, 20, 25, 'ALCUN', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  (0, 3, 9, 'ALCUNA', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  (23, 0, 5, 'ALLOR', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  (1, 5, 9, 'ALTE', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (2, 23, 27, 'ALTI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  (0, 23, 27, 'ALTO', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  (11, 10, 15, 'ALTRA', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  (12, 20, 25, 'ALTRA', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (3, 24, 29, 'ALTRA', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  (7, 24, 29, 'ALTRA', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  (8, 24, 29, 'ALTRI', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  (2, 28, 33, 'AMORE', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  (40, 0, 5, 'ANCHE', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  (7, 19, 24, 'ANCOR', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  (2, 6, 12, 'ANGELI', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  (7, 18, 23, 'ANIMA', 'E TU CHE SE COSTI ANIMA VIVA'),
#  (8, 21, 26, 'ANIMA', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  (2, 9, 14, 'ANIME', 'TEGNON L ANIME TRISTE DI COLORO'),
#  (8, 9, 14, 'ANIME', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  (10, 20, 25, 'ANIME', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  (1, 22, 28, 'ANTICO', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  (3, 6, 14, 'APPRESSO', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (4, 3, 10, 'ATTENDE', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  (8, 15, 20, 'AUGEL', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  (12, 29, 33, 'AUNA', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  (1, 16, 20, 'AURA', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  (8, 7, 14, 'AUTUNNO', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  (1, 2, 8, 'AVANTI', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  (4, 8, 12, 'AVEA', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (7, 22, 26, 'AVEA', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  (2, 18, 24, 'AVEREI', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  (3, 18, 24, 'AVESSE', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  (1, 23, 31, 'AVREBBER', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  (11, 28, 33, 'BAGNA', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  (8, 4, 10, 'BALENO', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  (5, 28, 33, 'BASSA', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  (1, 32, 37, 'BASSI', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  (37, 0, 5, 'BATTE', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  (0, 35, 40, 'BELLI', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  (84, 0, 3, 'BEN', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  (4, 19, 22, 'BEN', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  (0, 0, 13, 'BESTEMMIAVANO', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  (3, 11, 17, 'BIANCO', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  (5, 27, 33, 'BRAGIA', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  (4, 25, 30, 'BREVE', 'RISPUOSE DICEROLTI MOLTO BREVE'),
#  (9, 29, 34, 'BRUNA', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  (16, 17, 21, 'BUIA', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  (14, 27, 32, 'BUONA', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  (17, 0, 1, 'C', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  (3, 0, 9, 'CACCIANLI', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  (6, 2, 7, 'CADDI', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  (9, 25, 30, 'CALDO', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  (0, 22, 30, 'CAMPAGNA', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  (14, 0, 7, 'CANGIAR', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  (36, 0, 5, 'CARON', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  (15, 10, 15, 'CARON', 'E PERO SE CARON DI TE SI LAGNA'),
#  (7, 13, 18, 'CARON', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  (2, 28, 35, 'CATTIVI', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  (0, 22, 29, 'CATTIVO', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  (11, 4, 9, 'CENNI', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  (4, 22, 27, 'CERTO', 'INCONTANENTE INTESI E CERTO FUI'),
#  (37, 0, 2, 'CH', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  (61, 0, 2, 'CH', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  (92, 0, 2, 'CH', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  (4, 4, 6, 'CH', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (9, 4, 6, 'CH', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  (18, 4, 6, 'CH', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  (3, 5, 7, 'CH', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (10, 6, 8, 'CH', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  (15, 7, 9, 'CH', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  (9, 9, 11, 'CH', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  (12, 15, 17, 'CH', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  (17, 16, 18, 'CH', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  (8, 22, 24, 'CH', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  (1, 25, 27, 'CH', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  (1, 27, 29, 'CH', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  (13, 0, 3, 'CHE', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  (26, 0, 3, 'CHE', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  (31, 0, 3, 'CHE', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  (35, 0, 3, 'CHE', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  (36, 0, 3, 'CHE', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  (37, 0, 3, 'CHE', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  (40, 0, 3, 'CHE', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  (42, 0, 3, 'CHE', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  (46, 0, 3, 'CHE', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  (63, 0, 3, 'CHE', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  (82, 0, 3, 'CHE', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  (87, 0, 3, 'CHE', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  (2, 2, 5, 'CHE', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (18, 3, 6, 'CHE', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  (13, 4, 7, 'CHE', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  (4, 5, 8, 'CHE', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  (8, 5, 8, 'CHE', 'E TU CHE SE COSTI ANIMA VIVA'),
#  (0, 6, 9, 'CHE', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (6, 6, 9, 'CHE', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  (14, 6, 9, 'CHE', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  (11, 7, 10, 'CHE', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  (17, 7, 10, 'CHE', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  (14, 9, 12, 'CHE', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  (6, 13, 16, 'CHE', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (8, 13, 16, 'CHE', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  (9, 13, 16, 'CHE', 'E IO MAESTRO CHE E TANTO GREVE'),
#  (2, 14, 17, 'CHE', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  (12, 15, 18, 'CHE', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  (14, 17, 20, 'CHE', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  (2, 19, 22, 'CHE', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  (13, 19, 22, 'CHE', 'PARTITI DA COTESTI CHE SON MORTI'),
#  (16, 21, 24, 'CHE', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  (15, 23, 26, 'CHE', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  (15, 24, 27, 'CHE', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  (20, 30, 33, 'CHE', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (4, 11, 18, 'CIASCUN', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  (5, 17, 24, 'CIASCUN', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  (4, 9, 14, 'CIECA', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  (2, 12, 16, 'CIEL', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  (11, 26, 31, 'CIELO', 'NON ISPERATE MAI VEDER LO CIELO'),
#  (3, 30, 35, 'CINTA', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (61, 0, 3, 'CIO', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  (0, 19, 24, 'CITTA', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  (17, 6, 9, 'COL', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  (8, 12, 16, 'COLA', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  (3, 8, 14, 'COLORE', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  (1, 17, 23, 'COLORE', 'QUESTE PAROLE DI COLORE OSCURO'),
#  (1, 25, 31, 'COLORO', 'TEGNON L ANIME TRISTE DI COLORO'),
#  (9, 26, 31, 'COLUI', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  (49, 0, 3, 'COM', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  (13, 0, 4, 'COME', 'COME LA RENA QUANDO TURBO SPIRA'),
#  (46, 0, 4, 'COME', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  (9, 8, 12, 'COME', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  (17, 10, 14, 'COME', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  (0, 13, 17, 'COME', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  (0, 13, 22, 'COMINCIAR', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  (14, 0, 3, 'CON', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  (11, 6, 9, 'CON', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  (8, 14, 17, 'CON', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  (0, 33, 36, 'CON', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (1, 30, 37, 'CONCEDI', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  (0, 26, 35, 'CONFORTAI', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  (3, 7, 14, 'CONOBBI', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  (3, 29, 34, 'CONTE', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  (2, 6, 15, 'CONVEGNON', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  (2, 7, 14, 'CONVIEN', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  (0, 11, 18, 'CONVIEN', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  (1, 16, 23, 'CONVIEN', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  (4, 30, 34, 'CORO', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  (1, 12, 19, 'CORREVA', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  (6, 29, 36, 'CORTESE', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  (6, 16, 20, 'COSE', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  (1, 22, 26, 'COSE', 'DINANZI A ME NON FUOR COSE CREATE'),
#  (5, 28, 32, 'COSE', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  (50, 0, 4, 'COSI', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  (9, 7, 11, 'COSI', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  (6, 12, 17, 'COSTI', 'E TU CHE SE COSTI ANIMA VIVA'),
#  (2, 30, 37, 'COSTUME', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  (3, 11, 18, 'COTESTI', 'PARTITI DA COTESTI CHE SON MORTI'),
#  (0, 27, 33, 'CREATE', 'DINANZI A ME NON FUOR COSE CREATE'),
#  (2, 25, 32, 'CREDUTO', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  (2, 26, 35, 'CRUCCIARE', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  (7, 27, 32, 'CRUDE', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  (22, 19, 22, 'CUI', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  (14, 4, 5, 'D', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  (14, 5, 6, 'D', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  (8, 13, 14, 'D', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (17, 17, 18, 'D', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  (27, 20, 21, 'D', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  (14, 21, 22, 'D', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  (16, 21, 22, 'D', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  (1, 24, 25, 'D', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  (12, 24, 25, 'D', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  (27, 24, 25, 'D', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  (1, 25, 26, 'D', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  (1, 32, 33, 'D', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  (55, 0, 2, 'DA', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  (58, 0, 2, 'DA', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  (9, 8, 10, 'DA', 'PARTITI DA COTESTI CHE SON MORTI'),
#  (16, 13, 15, 'DA', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  (33, 0, 2, 'DE', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  (10, 12, 14, 'DE', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  (15, 15, 17, 'DE', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (23, 19, 21, 'DE', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  (4, 23, 25, 'DE', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  (10, 16, 19, 'DEL', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  (6, 29, 34, 'DENTI', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  (1, 8, 14, 'DENTRO', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  (0, 34, 39, 'DETTO', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (46, 0, 2, 'DI', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  (89, 0, 2, 'DI', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  (6, 5, 7, 'DI', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  (11, 6, 8, 'DI', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  (21, 6, 8, 'DI', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  (11, 7, 9, 'DI', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  (17, 9, 11, 'DI', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  (25, 9, 11, 'DI', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  (1, 14, 16, 'DI', 'QUESTE PAROLE DI COLORE OSCURO'),
#  (5, 14, 16, 'DI', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  (7, 14, 16, 'DI', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  (25, 16, 18, 'DI', 'E PERO SE CARON DI TE SI LAGNA'),
#  (18, 17, 19, 'DI', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  (26, 17, 19, 'DI', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  (19, 18, 20, 'DI', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  (2, 22, 24, 'DI', 'TEGNON L ANIME TRISTE DI COLORO'),
#  (12, 23, 25, 'DI', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  (21, 24, 26, 'DI', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  (5, 26, 28, 'DI', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (9, 26, 28, 'DI', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  (20, 27, 29, 'DI', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  (26, 27, 29, 'DI', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  (1, 17, 26, 'DIBATTERO', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  (0, 9, 18, 'DICEROLTI', 'RISPUOSE DICEROLTI MOLTO BREVE'),
#  (8, 19, 24, 'DIEDE', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  (7, 30, 35, 'DIEDI', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  (0, 2, 8, 'DIETRO', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  (0, 27, 36, 'DIMANDARE', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  (6, 6, 13, 'DIMONIO', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  (1, 0, 7, 'DINANZI', 'DINANZI A ME NON FUOR COSE CREATE'),
#  (5, 2, 5, 'DIO', 'A DIO SPIACENTI E A NEMICI SUI'),
#  (7, 14, 17, 'DIO', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  (3, 16, 19, 'DIO', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  (15, 27, 30, 'DIO', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  (21, 30, 33, 'DIO', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  (16, 17, 20, 'DIR', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  (8, 31, 34, 'DIR', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  (1, 7, 15, 'DISCERNO', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  (4, 24, 31, 'DISCESE', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  (0, 25, 33, 'DISFATTA', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  (13, 27, 32, 'DISIO', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  (28, 0, 5, 'DISSE', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  (9, 13, 18, 'DISSE', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  (11, 0, 5, 'DISSI', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  (9, 10, 15, 'DISSI', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  (4, 0, 7, 'DIVERSE', 'DIVERSE LINGUE ORRIBILI FAVELLE'),
#  (12, 7, 13, 'DIVINA', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  (0, 10, 16, 'DIVINA', 'FECEMI LA DIVINA PODESTATE'),
#  (0, 25, 32, 'DOLENTE', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  (2, 10, 16, 'DOLORE', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  (0, 26, 32, 'DOLORE', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  (0, 23, 31, 'DOLOROSE', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  (12, 17, 21, 'DOVE', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  (12, 4, 8, 'DUCA', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  (1, 25, 29, 'DUOL', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (3, 28, 32, 'DURO', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  (0, 35, 39, 'DURO', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (18, 0, 1, 'E', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (30, 0, 1, 'E', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (32, 0, 1, 'E', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (42, 0, 1, 'E', 'E IO MAESTRO CHE E TANTO GREVE'),
#  (46, 0, 1, 'E', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  (51, 0, 1, 'E', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  (54, 0, 1, 'E', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  (69, 0, 1, 'E', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  (87, 0, 1, 'E', 'E TU CHE SE COSTI ANIMA VIVA'),
#  (93, 0, 1, 'E', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  (118, 0, 1, 'E', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  (123, 0, 1, 'E', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  (127, 0, 1, 'E', 'E PERO SE CARON DI TE SI LAGNA'),
#  (135, 0, 1, 'E', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  (8, 5, 6, 'E', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  (13, 10, 11, 'E', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (1, 11, 12, 'E', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (6, 11, 12, 'E', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  (15, 13, 14, 'E', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  (19, 13, 14, 'E', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  (0, 15, 16, 'E', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  (17, 15, 16, 'E', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  (18, 15, 16, 'E', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (19, 15, 16, 'E', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  (12, 16, 17, 'E', 'A DIO SPIACENTI E A NEMICI SUI'),
#  (15, 17, 18, 'E', 'E IO MAESTRO CHE E TANTO GREVE'),
#  (27, 17, 18, 'E', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  (1, 18, 19, 'E', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  (5, 18, 19, 'E', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  (18, 18, 19, 'E', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  (5, 19, 20, 'E', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (10, 20, 21, 'E', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  (13, 20, 21, 'E', 'INCONTANENTE INTESI E CERTO FUI'),
#  (1, 21, 22, 'E', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  (14, 23, 24, 'E', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  (7, 24, 25, 'E', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  (23, 24, 25, 'E', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (11, 29, 30, 'E', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  (15, 30, 31, 'E', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  (5, 31, 32, 'E', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  (8, 31, 32, 'E', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  (0, 33, 34, 'E', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (2, 34, 35, 'E', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (7, 15, 19, 'EBBI', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  (9, 3, 7, 'ECCO', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  (12, 0, 2, 'ED', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  (29, 0, 2, 'ED', 'ED ELLI A ME QUESTO MISERO MODO'),
#  (64, 0, 2, 'ED', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  (70, 0, 2, 'ED', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  (27, 0, 4, 'ELLE', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  (0, 37, 41, 'ELLE', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (1, 3, 7, 'ELLI', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  (3, 3, 7, 'ELLI', 'ED ELLI A ME QUESTO MISERO MODO'),
#  (8, 3, 7, 'ELLI', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  (1, 34, 38, 'ELLI', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  (4, 11, 14, 'ERA', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  (10, 20, 23, 'ERA', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  (10, 18, 22, 'ERAN', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  (10, 25, 29, 'ERAN', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  (21, 0, 5, 'ERANO', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  (2, 15, 20, 'ERROR', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (3, 22, 27, 'ESSER', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  (2, 25, 30, 'ESSER', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  (0, 7, 14, 'ETTERNE', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  (1, 14, 21, 'ETTERNE', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  (0, 18, 25, 'ETTERNO', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  (1, 20, 27, 'ETTERNO', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  (12, 3, 5, 'FA', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  (4, 22, 24, 'FA', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  (3, 0, 8, 'FACEVANO', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  (20, 0, 4, 'FAMA', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  (0, 3, 13, 'FASTIDIOSI', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  (0, 28, 35, 'FATTORE', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  (0, 24, 31, 'FAVELLE', 'DIVERSE LINGUE ORRIBILI FAVELLE'),
#  (7, 4, 8, 'FECE', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  (1, 0, 6, 'FECEMI', 'FECEMI LA DIVINA PODESTATE'),
#  (5, 7, 13, 'FEDELI', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  (1, 11, 19, 'FERMEREM', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  (5, 30, 36, 'FIAMME', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  (8, 24, 28, 'FIER', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  (13, 0, 8, 'FIGLIUOL', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  (16, 26, 29, 'FIN', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (34, 0, 6, 'FINITO', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  (0, 12, 18, 'FIOCHE', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (2, 23, 28, 'FIOCO', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  (10, 10, 15, 'FIUME', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  (3, 31, 36, 'FIUME', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  (7, 27, 33, 'FOGLIE', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  (35, 0, 5, 'FORTE', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  (11, 9, 14, 'FORTE', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  (4, 28, 33, 'FORTE', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  (6, 24, 29, 'FOSSE', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  (12, 28, 31, 'FUI', 'INCONTANENTE INTESI E CERTO FUI'),
#  (10, 7, 11, 'FUOR', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  (1, 17, 21, 'FUOR', 'DINANZI A ME NON FUOR COSE CREATE'),
#  (4, 30, 35, 'FUORO', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  (5, 3, 6, 'FUR', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  (4, 29, 32, 'FUR', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  (3, 21, 26, 'FURON', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  (2, 35, 39, 'GELO', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  (2, 6, 10, 'GENT', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (2, 3, 8, 'GENTE', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  (0, 28, 33, 'GENTE', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  (3, 5, 10, 'GENTI', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  (2, 17, 22, 'GENTI', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  (2, 4, 11, 'GIRANDO', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  (12, 0, 8, 'GITTANSI', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  (0, 0, 9, 'GIUSTIZIA', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  (0, 14, 23, 'GIUSTIZIA', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  (0, 15, 24, 'GIUSTIZIA', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  (3, 10, 16, 'GLORIA', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  (14, 28, 32, 'GOTE', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  (6, 24, 28, 'GRAN', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  (10, 26, 30, 'GRAN', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  (11, 30, 35, 'GRAVE', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  (3, 25, 30, 'GREVE', 'E IO MAESTRO CHE E TANTO GREVE'),
#  (9, 0, 8, 'GRIDANDO', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  (8, 9, 13, 'GUAI', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  (6, 28, 32, 'GUAI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  (2, 24, 30, 'GUARDA', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  (0, 2, 7, 'HANNO', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  (2, 11, 16, 'HANNO', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  (1, 31, 33, 'HO', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (85, 0, 1, 'I', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  (12, 3, 4, 'I', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  (17, 10, 11, 'I', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  (5, 12, 13, 'I', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  (14, 17, 18, 'I', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  (14, 26, 27, 'I', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  (4, 27, 28, 'I', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (22, 27, 28, 'I', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  (8, 28, 29, 'I', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  (5, 6, 12, 'IGNUDI', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  (11, 12, 14, 'IL', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  (13, 13, 15, 'IL', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  (1, 16, 18, 'IL', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  (3, 16, 18, 'IL', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  (2, 18, 20, 'IL', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (4, 20, 22, 'IL', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  (10, 21, 23, 'IL', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  (13, 27, 29, 'IL', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  (12, 7, 9, 'IN', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  (10, 22, 24, 'IN', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  (26, 24, 26, 'IN', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  (1, 0, 12, 'INCONTANENTE', 'INCONTANENTE INTESI E CERTO FUI'),
#  (1, 25, 32, 'INDEGNA', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  (2, 15, 22, 'INFERNO', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  (21, 0, 6, 'INFINO', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  (3, 30, 37, 'INSIEME', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  (0, 28, 38, 'INTELLETTO', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  (4, 13, 19, 'INTESI', 'INCONTANENTE INTESI E CERTO FUI'),
#  (0, 30, 37, 'INTRATE', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  (2, 2, 4, 'IO', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (4, 2, 4, 'IO', 'E IO MAESTRO CHE E TANTO GREVE'),
#  (7, 2, 4, 'IO', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  (3, 4, 6, 'IO', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  (19, 4, 6, 'IO', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  (7, 7, 9, 'IO', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (10, 7, 9, 'IO', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  (18, 7, 9, 'IO', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  (19, 10, 12, 'IO', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  (3, 17, 19, 'IO', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  (15, 19, 21, 'IO', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  (2, 20, 22, 'IO', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  (16, 23, 26, 'IRA', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  (5, 27, 30, 'IRA', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  (3, 4, 12, 'ISPERATE', 'NON ISPERATE MAI VEDER LO CIELO'),
#  (8, 30, 33, 'IVI', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  (103, 0, 1, 'L', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (112, 0, 1, 'L', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (13, 2, 3, 'L', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  (13, 7, 8, 'L', 'TEGNON L ANIME TRISTE DI COLORO'),
#  (10, 11, 12, 'L', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  (33, 13, 14, 'L', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  (4, 14, 15, 'L', 'RISONAVAN PER L AERE SANZA STELLE'),
#  (12, 15, 16, 'L', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  (1, 16, 17, 'L', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  (30, 17, 18, 'L', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (22, 18, 19, 'L', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (23, 19, 20, 'L', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  (1, 20, 21, 'L', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  (24, 21, 22, 'L', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  (11, 22, 23, 'L', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  (19, 22, 23, 'L', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  (29, 25, 26, 'L', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  (3, 26, 27, 'L', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  (20, 26, 27, 'L', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (3, 34, 35, 'L', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (0, 36, 37, 'L', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (5, 0, 2, 'LA', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  (112, 0, 2, 'LA', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  (113, 0, 2, 'LA', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  (115, 0, 2, 'LA', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  (6, 2, 4, 'LA', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  (14, 3, 5, 'LA', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  (27, 4, 6, 'LA', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  (2, 5, 7, 'LA', 'COME LA RENA QUANDO TURBO SPIRA'),
#  (3, 7, 9, 'LA', 'FECEMI LA DIVINA PODESTATE'),
#  (28, 7, 9, 'LA', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  (31, 7, 9, 'LA', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  (8, 10, 12, 'LA', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (18, 13, 15, 'LA', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  (14, 14, 16, 'LA', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  (9, 15, 17, 'LA', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  (11, 15, 17, 'LA', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  (0, 16, 18, 'LA', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  (0, 17, 19, 'LA', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  (15, 18, 20, 'LA', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  (4, 21, 23, 'LA', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (19, 21, 23, 'LA', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  (3, 24, 26, 'LA', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (13, 25, 30, 'LAGNA', 'E PERO SE CARON DI TE SI LAGNA'),
#  (1, 26, 34, 'LAGRIMAI', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  (3, 17, 24, 'LAGRIME', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  (3, 9, 18, 'LAGRIMOSA', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  (0, 10, 18, 'LAMENTAR', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  (0, 21, 27, 'LANOSE', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  (0, 15, 23, 'LASCIARE', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  (1, 0, 8, 'LASCIATE', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  (0, 32, 37, 'LASSA', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  (5, 23, 28, 'LASSE', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  (62, 0, 2, 'LE', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  (17, 3, 5, 'LE', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  (8, 9, 11, 'LE', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  (19, 13, 15, 'LE', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  (2, 14, 16, 'LE', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  (7, 17, 19, 'LE', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  (25, 17, 19, 'LE', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  (12, 18, 20, 'LE', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  (14, 22, 24, 'LE', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  (15, 22, 24, 'LE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  (22, 24, 26, 'LE', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  (12, 10, 15, 'LEGNO', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  (10, 18, 23, 'LEVAN', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  (5, 3, 5, 'LI', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  (22, 10, 12, 'LI', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  (25, 13, 15, 'LI', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  (7, 19, 21, 'LI', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  (15, 20, 22, 'LI', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  (14, 21, 23, 'LI', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  (10, 23, 25, 'LI', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  (25, 24, 26, 'LI', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  (8, 25, 27, 'LI', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  (0, 4, 9, 'LIETO', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  (9, 4, 9, 'LIEVE', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  (2, 8, 14, 'LINGUE', 'DIVERSE LINGUE ORRIBILI FAVELLE'),
#  (15, 17, 21, 'LITO', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  (4, 18, 24, 'LIVIDA', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  (7, 3, 5, 'LO', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  (14, 20, 22, 'LO', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  (20, 22, 24, 'LO', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  (17, 23, 25, 'LO', 'NON ISPERATE MAI VEDER LO CIELO'),
#  (21, 26, 28, 'LO', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  (1, 19, 23, 'LOCO', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (9, 19, 23, 'LOCO', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (0, 32, 36, 'LODO', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  (3, 2, 5, 'LOR', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  (16, 3, 6, 'LOR', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  (3, 5, 8, 'LOR', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  (13, 13, 16, 'LOR', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  (12, 17, 20, 'LOR', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  (15, 20, 23, 'LOR', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  (16, 20, 23, 'LOR', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  (1, 27, 30, 'LOR', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (11, 27, 30, 'LOR', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  (44, 0, 4, 'LORO', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  (5, 8, 12, 'LORO', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  (11, 15, 19, 'LUCE', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  (11, 9, 12, 'LUI', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  (3, 29, 33, 'LUME', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  (4, 21, 26, 'LUNGA', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  (0, 31, 32, 'M', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (76, 0, 2, 'MA', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  (85, 0, 2, 'MA', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  (8, 20, 22, 'MA', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  (8, 21, 23, 'MA', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  (0, 5, 12, 'MAESTRO', 'E IO MAESTRO CHE E TANTO GREVE'),
#  (1, 6, 13, 'MAESTRO', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  (0, 10, 17, 'MAESTRO', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (0, 16, 23, 'MAESTRO', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  (0, 21, 28, 'MAESTRO', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  (17, 13, 16, 'MAI', 'NON ISPERATE MAI VEDER LO CIELO'),
#  (23, 17, 20, 'MAI', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  (8, 21, 24, 'MAI', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  (10, 15, 18, 'MAL', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  (4, 26, 34, 'MALVAGIA', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  (1, 29, 32, 'MAN', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (4, 17, 21, 'MANO', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (0, 4, 6, 'ME', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  (1, 4, 6, 'ME', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  (2, 4, 6, 'ME', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  (5, 10, 12, 'ME', 'DINANZI A ME NON FUOR COSE CREATE'),
#  (7, 10, 12, 'ME', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  (14, 10, 12, 'ME', 'ED ELLI A ME QUESTO MISERO MODO'),
#  (21, 10, 12, 'ME', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  (2, 31, 34, 'MEN', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  (2, 12, 19, 'MENARVI', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  (9, 3, 8, 'MENTE', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  (18, 0, 2, 'MI', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  (13, 8, 10, 'MI', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  (9, 16, 18, 'MI', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  (5, 23, 25, 'MI', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  (27, 25, 27, 'MI', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  (16, 26, 28, 'MI', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  (15, 27, 29, 'MI', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  (16, 27, 29, 'MI', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  (17, 27, 29, 'MI', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  (3, 27, 30, 'MIA', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (16, 9, 12, 'MIO', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  (16, 13, 16, 'MIO', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  (1, 19, 22, 'MIO', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  (2, 0, 9, 'MISCHIATE', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  (1, 4, 13, 'MISCHIATO', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  (2, 3, 7, 'MISE', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  (0, 0, 12, 'MISERICORDIA', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  (3, 20, 26, 'MISERO', 'ED ELLI A ME QUESTO MISERO MODO'),
#  (3, 27, 31, 'MODO', 'ED ELLI A ME QUESTO MISERO MODO'),
#  (2, 19, 24, 'MOLTO', 'RISPUOSE DICEROLTI MOLTO BREVE'),
#  (8, 25, 30, 'MOLTO', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  (0, 16, 21, 'MONDO', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  (0, 31, 36, 'MORTA', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  (5, 4, 9, 'MORTE', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  (1, 29, 34, 'MORTE', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  (5, 27, 32, 'MORTI', 'PARTITI DA COTESTI CHE SON MORTI'),
#  (0, 3, 10, 'MOSCONI', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  (0, 10, 15, 'MOSSE', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  (6, 11, 17, 'MUOION', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  (11, 16, 17, 'N', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  (6, 33, 34, 'N', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  (0, 24, 34, 'NASCIMENTI', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  (13, 28, 32, 'NAVE', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  (34, 0, 2, 'NE', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  (36, 0, 2, 'NE', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  (74, 0, 2, 'NE', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  (0, 13, 15, 'NE', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  (1, 13, 15, 'NE', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  (20, 18, 20, 'NE', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  (7, 23, 25, 'NE', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  (4, 21, 24, 'NEL', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (4, 20, 26, 'NEMICI', 'A DIO SPIACENTI E A NEMICI SUI'),
#  (3, 17, 23, 'NFAMIA', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  (6, 8, 10, 'NO', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  (1, 3, 11, 'NOCCHIER', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  (12, 0, 3, 'NOI', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (10, 7, 10, 'NOI', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  (5, 14, 17, 'NOI', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  (34, 0, 3, 'NON', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  (55, 0, 3, 'NON', 'NON ISPERATE MAI VEDER LO CIELO'),
#  (1, 3, 6, 'NON', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  (6, 7, 10, 'NON', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  (19, 7, 10, 'NON', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  (1, 13, 16, 'NON', 'DINANZI A ME NON FUOR COSE CREATE'),
#  (3, 14, 17, 'NON', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  (9, 17, 20, 'NON', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  (18, 17, 20, 'NON', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  (14, 19, 22, 'NON', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  (6, 21, 24, 'NON', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  (7, 22, 25, 'NON', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  (12, 23, 26, 'NON', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  (9, 25, 28, 'NON', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  (9, 28, 31, 'NON', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  (7, 31, 34, 'NON', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  (2, 23, 29, 'NOSTRI', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  (3, 28, 34, 'NSEGNA', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  (5, 10, 16, 'NTESER', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  (7, 4, 10, 'NTORNO', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  (5, 31, 35, 'NUDE', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  (8, 13, 18, 'NUOVA', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  (0, 4, 12, 'NVIDIOSI', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  (6, 13, 18, 'OCCHI', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  (4, 16, 21, 'OCCHI', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  (9, 18, 23, 'OCCHI', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  (4, 30, 33, 'ODO', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  (5, 0, 4, 'OGNE', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  (5, 6, 10, 'OGNE', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  (1, 9, 13, 'OGNE', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  (4, 19, 23, 'OGNE', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  (8, 22, 26, 'OGNE', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  (1, 24, 28, 'OGNE', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  (5, 21, 26, 'OLTRE', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  (12, 16, 20, 'OMAI', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  (6, 17, 22, 'OMBRA', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  (0, 16, 19, 'OND', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  (15, 24, 28, 'ONDA', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  (11, 24, 26, 'OR', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  (1, 15, 23, 'ORRIBILI', 'DIVERSE LINGUE ORRIBILI FAVELLE'),
#  (0, 24, 30, 'OSCURO', 'QUESTE PAROLE DI COLORE OSCURO'),
#  (2, 24, 26, 'OV', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (11, 27, 32, 'PAESE', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  (5, 25, 31, 'PALUDE', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  (6, 17, 20, 'PAR', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (3, 19, 24, 'PAREA', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  (2, 24, 31, 'PARENTI', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  (4, 19, 24, 'PARER', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  (6, 20, 26, 'PARLAR', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  (7, 0, 6, 'PAROLE', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  (1, 7, 13, 'PAROLE', 'QUESTE PAROLE DI COLORE OSCURO'),
#  (7, 20, 26, 'PAROLE', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  (13, 0, 7, 'PARTITI', 'PARTITI DA COTESTI CHE SON MORTI'),
#  (2, 29, 36, 'PARTIVA', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  (10, 11, 16, 'PASSA', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  (2, 33, 38, 'PASSA', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  (3, 29, 36, 'PASSARE', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  (10, 30, 35, 'PASSI', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  (5, 29, 33, 'PELO', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  (0, 0, 3, 'PER', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  (1, 0, 3, 'PER', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  (2, 0, 3, 'PER', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  (9, 0, 3, 'PER', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (17, 0, 3, 'PER', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  (48, 0, 3, 'PER', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  (76, 0, 3, 'PER', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  (13, 6, 9, 'PER', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  (7, 8, 11, 'PER', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  (7, 9, 12, 'PER', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  (4, 10, 13, 'PER', 'RISONAVAN PER L AERE SANZA STELLE'),
#  (8, 16, 19, 'PER', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  (10, 17, 20, 'PER', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  (8, 18, 21, 'PER', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  (14, 18, 21, 'PER', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  (13, 20, 23, 'PER', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  (13, 21, 24, 'PER', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  (6, 23, 26, 'PER', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  (11, 24, 27, 'PER', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  (14, 25, 28, 'PER', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  (0, 20, 27, 'PERDUTA', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  (0, 8, 15, 'PERDUTO', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  (6, 2, 6, 'PERO', 'E PERO SE CARON DI TE SI LAGNA'),
#  (1, 18, 25, 'PERSONA', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  (4, 9, 16, 'PIAGGIA', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  (1, 6, 15, 'PIANGENDO', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  (1, 14, 20, 'PIANTI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  (2, 31, 36, 'PIEDI', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  (7, 29, 35, 'PIGLIA', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  (59, 0, 3, 'PIU', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  (15, 19, 22, 'PIU', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  (0, 17, 26, 'PODESTATE', 'FECEMI LA DIVINA PODESTATE'),
#  (67, 0, 3, 'POI', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  (1, 2, 5, 'POI', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (6, 2, 5, 'POI', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  (13, 3, 6, 'POI', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  (1, 30, 35, 'PORTA', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  (13, 30, 35, 'PORTI', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  (4, 31, 36, 'PORTI', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  (3, 11, 15, 'POSA', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  (16, 0, 6, 'POSCIA', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  (10, 26, 31, 'PRAVE', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  (0, 22, 27, 'PRIMO', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  (0, 6, 14, 'PROFONDO', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  (5, 28, 34, 'PRONTE', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  (2, 2, 8, 'PRONTI', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  (15, 4, 8, 'PUOI', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  (1, 31, 36, 'PUOSE', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (10, 25, 30, 'PUOTE', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  (15, 9, 12, 'QUA', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  (16, 3, 7, 'QUAL', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  (3, 23, 27, 'QUAL', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  (11, 25, 29, 'QUAL', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  (4, 12, 17, 'QUALI', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  (2, 15, 24, 'QUALUNQUE', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  (19, 0, 6, 'QUANDO', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  (1, 13, 19, 'QUANDO', 'COME LA RENA QUANDO TURBO SPIRA'),
#  (4, 23, 29, 'QUANTE', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  (10, 12, 16, 'QUEL', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  (7, 17, 21, 'QUEL', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  (4, 20, 24, 'QUEL', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  (7, 3, 8, 'QUELL', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  (5, 10, 15, 'QUELL', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  (32, 0, 6, 'QUELLI', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  (4, 4, 10, 'QUESTA', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  (4, 0, 6, 'QUESTE', 'QUESTE PAROLE DI COLORE OSCURO'),
#  (14, 0, 6, 'QUESTI', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  (18, 0, 6, 'QUESTI', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  (13, 7, 13, 'QUESTO', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  (2, 13, 19, 'QUESTO', 'ED ELLI A ME QUESTO MISERO MODO'),
#  (7, 12, 17, 'QUETE', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  (10, 0, 3, 'QUI', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  (17, 16, 19, 'QUI', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  (10, 21, 24, 'QUI', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  (2, 23, 26, 'QUI', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  (26, 0, 6, 'QUINCI', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  (33, 0, 6, 'QUINCI', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  (5, 0, 5, 'QUIVI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  (0, 25, 34, 'RACCOGLIE', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  (0, 4, 13, 'RAGIONIAM', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  (0, 36, 40, 'RAMO', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (7, 26, 31, 'RATTA', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  (33, 0, 5, 'RATTO', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  (5, 19, 22, 'REI', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  (15, 10, 14, 'REMO', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  (3, 8, 12, 'RENA', 'COME LA RENA QUANDO TURBO SPIRA'),
#  (0, 27, 34, 'RIBELLI', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  (4, 26, 32, 'RICEVE', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  (1, 29, 37, 'RICHIAMO', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  (1, 24, 31, 'RICOLTO', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  (0, 26, 38, 'RICONOSCIUTO', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  (1, 29, 36, 'RIFIUTO', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  (1, 5, 12, 'RIGAVAN', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  (1, 9, 18, 'RIGUARDAI', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  (0, 11, 20, 'RIGUARDAR', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  (16, 29, 32, 'RIO', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  (1, 0, 9, 'RISONAVAN', 'RISONAVAN PER L AERE SANZA STELLE'),
#  (6, 0, 8, 'RISPUOSE', 'RISPUOSE DICEROLTI MOLTO BREVE'),
#  (1, 7, 16, 'RITRASSER', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  (4, 16, 20, 'RIVA', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  (8, 21, 25, 'RIVA', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  (14, 30, 34, 'RIVA', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  (2, 13, 20, 'RIVIERA', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  (1, 37, 41, 'ROTE', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  (24, 25, 26, 'S', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  (28, 27, 28, 'S', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  (7, 28, 29, 'S', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  (5, 20, 26, 'SANGUE', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  (1, 11, 16, 'SANZA', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  (1, 21, 26, 'SANZA', 'RISONAVAN PER L AERE SANZA STELLE'),
#  (2, 21, 26, 'SANZA', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  (5, 26, 31, 'SANZA', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  (6, 9, 15, 'SAPERE', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  (0, 9, 17, 'SAPIENZA', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  (2, 5, 11, 'SAPPIA', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  (1, 19, 26, 'SCHIERA', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  (0, 7, 16, 'SCIAURATI', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  (1, 7, 14, 'SCRITTE', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  (2, 28, 34, 'SDEGNA', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  (7, 0, 2, 'SE', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  (33, 7, 9, 'SE', 'E PERO SE CARON DI TE SI LAGNA'),
#  (13, 9, 11, 'SE', 'E TU CHE SE COSTI ANIMA VIVA'),
#  (10, 27, 29, 'SE', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  (2, 20, 27, 'SEGRETE', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  (10, 19, 23, 'SEME', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  (0, 38, 42, 'SEME', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (6, 7, 14, 'SEMENZA', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  (9, 0, 6, 'SEMPRE', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  (10, 5, 8, 'SEN', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  (0, 21, 26, 'SENSO', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  (0, 25, 35, 'SENTIMENTO', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  (5, 18, 23, 'SETTA', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  (107, 0, 2, 'SI', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  (5, 4, 6, 'SI', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  (25, 4, 6, 'SI', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  (23, 6, 8, 'SI', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  (0, 7, 9, 'SI', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  (1, 7, 9, 'SI', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  (2, 7, 9, 'SI', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  (10, 8, 10, 'SI', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  (14, 15, 17, 'SI', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  (19, 15, 17, 'SI', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  (4, 18, 20, 'SI', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  (12, 22, 24, 'SI', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  (18, 22, 24, 'SI', 'E PERO SE CARON DI TE SI LAGNA'),
#  (6, 25, 27, 'SI', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  (16, 25, 27, 'SI', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  (5, 30, 32, 'SI', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (2, 27, 30, 'SIA', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  (0, 4, 8, 'SIAM', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (9, 13, 17, 'SIEN', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  (3, 0, 11, 'SIMILEMENTE', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  (0, 3, 8, 'SOMMA', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  (1, 18, 23, 'SOMMO', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  (10, 13, 16, 'SON', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  (11, 23, 26, 'SON', 'PARTITI DA COTESTI CHE SON MORTI'),
#  (7, 23, 28, 'SONNO', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  (12, 9, 13, 'SONO', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  (6, 10, 14, 'SONO', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  (6, 18, 22, 'SONO', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  (5, 30, 35, 'SORTE', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  (0, 29, 37, 'SOSPETTO', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  (0, 6, 13, 'SOSPIRI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  (2, 25, 33, 'SPAVENTO', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  (0, 14, 22, 'SPERANZA', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  (1, 17, 25, 'SPERANZA', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  (4, 8, 14, 'SPEZIE', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (0, 6, 15, 'SPIACENTI', 'A DIO SPIACENTI E A NEMICI SUI'),
#  (4, 26, 31, 'SPIRA', 'COME LA RENA QUANDO TURBO SPIRA'),
#  (4, 29, 36, 'SPOGLIE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  (8, 27, 33, 'SPRONA', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  (1, 27, 33, 'STELLE', 'RISONAVAN PER L AERE SANZA STELLE'),
#  (1, 15, 24, 'STIMOLATI', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  (66, 0, 2, 'SU', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  (18, 15, 17, 'SU', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  (3, 13, 16, 'SUA', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  (4, 12, 18, 'SUDORE', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  (18, 25, 28, 'SUE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  (10, 27, 30, 'SUI', 'A DIO SPIACENTI E A NEMICI SUI'),
#  (20, 25, 28, 'SUO', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  (23, 27, 30, 'SUO', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  (2, 21, 25, 'SUON', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (1, 35, 40, 'SUONA', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  (1, 29, 30, 'T', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (8, 10, 15, 'TANTA', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  (1, 19, 24, 'TANTO', 'E IO MAESTRO CHE E TANTO GREVE'),
#  (5, 20, 25, 'TANTO', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  (2, 22, 27, 'TANTO', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  (22, 19, 21, 'TE', 'E PERO SE CARON DI TE SI LAGNA'),
#  (10, 0, 6, 'TEGNON', 'TEGNON L ANIME TRISTE DI COLORO'),
#  (18, 10, 14, 'TEMA', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  (3, 35, 39, 'TEME', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  (11, 0, 7, 'TEMENDO', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  (2, 27, 32, 'TEMPO', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  (10, 28, 33, 'TEMPO', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (4, 6, 13, 'TENEBRE', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  (10, 3, 8, 'TERRA', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  (14, 10, 15, 'TERRA', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  (2, 24, 29, 'TESTA', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  (13, 21, 23, 'TI', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  (19, 23, 25, 'TI', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  (16, 28, 30, 'TI', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  (0, 33, 38, 'TINTA', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  (0, 13, 16, 'TRA', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  (2, 9, 18, 'TRAPASSAR', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  (0, 16, 25, 'TRAPASSAR', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  (4, 30, 36, 'TRASSI', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  (3, 27, 33, 'TRATTA', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  (46, 0, 5, 'TREMO', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  (6, 6, 12, 'TRISTA', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  (2, 15, 21, 'TRISTE', 'TEGNON L ANIME TRISTE DI COLORO'),
#  (12, 2, 4, 'TU', 'E TU CHE SE COSTI ANIMA VIVA'),
#  (7, 4, 6, 'TU', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  (0, 12, 19, 'TUMULTO', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  (3, 20, 25, 'TURBO', 'COME LA RENA QUANDO TURBO SPIRA'),
#  (5, 16, 21, 'TUTTE', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  (6, 16, 21, 'TUTTE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  (10, 17, 22, 'TUTTE', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  (43, 0, 5, 'TUTTI', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  (3, 2, 7, 'UMANA', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  (71, 0, 2, 'UN', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  (3, 9, 11, 'UN', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  (13, 23, 25, 'UN', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  (9, 2, 5, 'UNA', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  (14, 11, 14, 'UNA', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  (6, 24, 27, 'UNA', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  (19, 25, 28, 'UNA', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  (1, 26, 29, 'UNA', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  (3, 32, 35, 'UNA', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  (14, 15, 18, 'UOM', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  (17, 19, 22, 'UOM', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  (16, 13, 14, 'V', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  (0, 10, 12, 'VA', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  (1, 10, 12, 'VA', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  (2, 10, 12, 'VA', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  (9, 9, 14, 'VANNO', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  (2, 3, 10, 'VECCHIO', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  (47, 0, 4, 'VEDE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  (8, 17, 22, 'VEDER', 'NON ISPERATE MAI VEDER LO CIELO'),
#  (4, 7, 13, 'VEDRAI', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  (2, 2, 7, 'VEGNO', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  (3, 12, 17, 'VENIA', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  (6, 18, 23, 'VENIR', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  (15, 25, 30, 'VENTO', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  (1, 9, 15, 'VENUTI', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  (0, 19, 29, 'VERGOGNOSI', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  (2, 14, 19, 'VERMI', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  (0, 20, 29, 'VERMIGLIA', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  (24, 0, 6, 'VERRAI', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  (3, 8, 13, 'VERSO', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  (1, 16, 21, 'VESPE', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  (12, 16, 19, 'VIA', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  (8, 0, 3, 'VID', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  (8, 11, 15, 'VIDE', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  (23, 0, 4, 'VIDI', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  (28, 0, 4, 'VIDI', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  (5, 19, 23, 'VIDI', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  (0, 5, 10, 'VILTA', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  (1, 13, 20, 'VILTADE', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  (11, 11, 16, 'VINSE', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  (1, 33, 38, 'VINTA', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  (0, 4, 10, 'VISSER', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  (5, 15, 19, 'VITA', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  (11, 24, 28, 'VIVA', 'E TU CHE SE COSTI ANIMA VIVA'),
#  (3, 33, 37, 'VIVI', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  (10, 0, 4, 'VOCI', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  (11, 16, 19, 'VOI', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  (1, 23, 26, 'VOI', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  (3, 10, 15, 'VOLTO', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  (6, 30, 35, 'VOLTO', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  (11, 18, 23, 'VOLVE', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  (7, 11, 16, 'VUOLE', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  (25, 0, 6, 'VUOLSI', 'VUOLSI COSI COLA DOVE SI PUOTE')]

# %% [markdown]
# ## Lemmatization
#
# *The philologist, however, must group or sort further on what the machine has not been able to «feel»; thus have, had are different forms of the same verb; thus, in Italian, andiamocene, diamogliene are several words joined into one, and for the Latin mortuus est is a single word form which means died, but could also mean the dead man is and then they would be two items; and so on for the whole wide range of homonyms.*
#
# ## Output
#
# *When the order has thus been properly modified and attains its final form, the cards are ready to be process in the Alphanumerical Accounting Machine, or Tabulator.
# The tabulator retranscribes on a sheet of paper, in letters and numbers— no longer in holes— line after line, the contents represented by the holes in the cards, at the rate of 4,800 cards per hour; and this is a page of the concordance or index in its final arrangement.*
#
# ## Headings
#
# *The concordance which I am presenting as an example is precisely an off-set reproduction of tabulated sheets turned out by the accounting machine. The tabulator's performance is extremely useful when, to use, the current technical phrase, it is running in tab. When another machine called the Summary Punch is connected to the accounting machine running in tab, while the latter is turning out the long tabulated list of different words, the former, electrically controlled by the accounting machine, simultanteously punches a new card for each of these words, thus providing ready headings to be placed before the single groups of lines or quotations. If necessary, these can be inserted in their proper place among all the others automatically by the collator.
#
# ## Phrases
#
# *This Collator which searches simultaneously two separate groups of cards at the rate of 20,000 per hour, and can insert, substitute and change cards from one with the cards from the other group, also offers some initial solutions to the problem of finding phrases or compound expressions. Taking, for example the expression according to: the group of cards containing according and that containing to are processed in the machine; on the basis of the identical quotation, the machine will extract all those cards on which both appear. It is true that they may be separated by other words, but one thing is certain, namely that all the cards bearing according to will be among those extracted; the eye and the hand must do the rest. It is still easier to obtain the same result when a card bearing the phrase sought for can be used as a pilot-card.*

# %% [markdown]
# ---
#
# CC-BY Stéfan Sinclair &amp; Geoffrey Rockwell
#
# Last updated September 14, 2016.
