# %% [markdown]
# # Punch Card Operations
#
# Stéfan Sinclair &amp; Geoffry Rockwell
#
# We're exploring here some of the operations and algorithms used by early computing humanists, including Father Roberto Busa. For this experiment we're considering in particular IBM engineer Paul Tasman's description "[Literary Data Processing](http://ieeexplore.ieee.org/document/5392686/?reload=true&arnumber=5392686)."

# %% [markdown]
# ## Data Entry of Phrases
#
# *The Automatic Punch, controlled by a keyboard similar to that of an ordinary typewriter, «wrote» by holes or perforations, one for each card, all the lines; a total of 136 cards. This is the sole work done by human eyes and fingers directly and responsibly; if at this point oversights occur, the error will be repeated from stage to stage; but if no mistakes were made, or were eliminated, there is no fear of fresh errors; human work from now onwards is reduced to mere supervision on the proper functioning of the various machines.*
#
# For the purposes of this replication we won't bother initially with the mechanics of a punchcard, we'll simply create an array of 136 strings which we'll then endeavour to treat as if they were punch cards.
#
# Rather than use a local data file for the Dante's *Divine Comedy*, we'll read from a [plain text URL](https://www.clear.rice.edu/comp200/resources/texts/Dante%20Divine%20Comedy.txt) (and assume that it will remain available), and then extract Canto III.

# %%
import urllib.request

# grab the entire Divine Comedy
inferno_url = 'https://raw.githubusercontent.com/zioproto/hadoop-swift-tutorial/master/dcu.txt'
with urllib.request.urlopen(inferno_url) as response:
   inferno_text = response.read().decode()

# %%
import re

# extract Canto III
canto3 = inferno_text[inferno_text.find("Inferno: Canto III") : inferno_text.find("Inferno: Canto IV")].strip()

# split the string into lines (removing the title line)
cards = re.split('\n+', canto3)[1:]
print("We have ", len(cards), '"cards" (or lines).')
# Out:
# We have  136 "cards" (or lines).

# %% [markdown]
# ## Checking the Data Entry
#
# *The collator can also be used to verify and correct the cards which have been manually punched at the beginning, and thus guarantee the accuracy of the transcription, an indispensable condition for philological works, particularly in the light of their peculiar function. Two separate typists punch the same text, each on his own; the collator compares the two series of cards, perceiving the discrepancies; of the cards not coinciding, at least one is wrong. This control allows only the following case to pass unobserved, namely two typists make the same error in the same place. This case is very improbable and so much the less probable in as much as the qualities and circumstances of typing and typist are different.*
#
# We don't need to check transcription, although there could be some discussion about possible typos and editorial decisions in this edition.
#
# ## Another Way of Checking
#
# *This method of verifying, although substantially the same, offers perhaps some advantages over the other, usually employed by IBM in the intent of not doubling the number, and consequently the cost, of the cards purposely, whereas in our case this is no hindrance, since each card already has to be multiplied as many times as the words it contains; the punched cards are put through the Verifier on the keys of which a typist repeats the sane text; the machine signals him when his punching does not concord with the existing holes; one of the two is wrong.*
#
# Again, this doesn't seem especially relevant.
#
# ## Transcribing
#
# *The contents of each card can be made legible either on the punch itself which, if required, can simultaneously write in letters on the upper edge of the card what is «written» in holes on the various lines of columns thereon; or else on a second machine, the so-called Interpreter, which transcribes in letters the holes it encounters on the cards (previously punched). This offers not only a more accurate transcription in virtue of the better type and greater spacing of the characters, but a transcription which can be effected on any desired portion of the card.*
#
# For now, since we're not reproducing the punch card object visually, this can be skipped.
#
# ## Tokenization
#
# *The 136 cards thus punched were then processed through a third machine, the Reproducer: this automatically copied them on another 136 cards, but adding, sideways of the lines and their quotations, the first of the words contained in each. Subsequently it makes a second copy, adding on the side the second word, then a third copy adding the third, and so forth. There were finally 943 cards, as many as were the words of the third canto of Dante's Inferno; thus each word in that canto had its card, accompanied by the text (or rather, here, by the line) and by the quotation.*
#
# *This is equivalent to state that each line was multiplied as many times as words it contained. I must confess that in actual practice this was not so simple as I endeavoured to make it in the description; the second and the successive words did not actually commence in the same column on all cards. In fact, it was this lack of determined fields which constituted the greatest hindrance in transposing the system from the commercial and statistical uses to the sorting of words from a literary text. The result was attained by exploring the cards, column by column, in order to identify by the non-punched columns the end of the previous word and the commencement of the following one; thus, operating with the sorter and reproducer together, were produced only those words commencing and finishing in the same columns.*
#
# So, before we begin this, an important step is needed to transform the text from each card into something more plausible. At the moment each line has been transcribed faithfully, but that's not what happened (even if it's not described). In particular, we need at least the following operations:
#
# * convert words to uppercase
# * filter out anything that's not part of a word (quotes, punctuation, based on the total number of cards, hyphens and apostrophes internal to words – like *l’etterno* – were also stripped)
# * strip out accented characters
# * normalize spacing (no leading or trailing spaces, single space between words)
#
# Presumably these operations would have been performed during the initial data entry, but we'll do it now since it wasn't made clear earlier.

# %%
import unicodedata

# convert to upper case
clean_cards = [line.upper() for line in cards]

# keep word characters only
clean_cards = [" ".join(re.findall(r'\b\w+\b', line.strip())) for line in clean_cards]

# remove accents
clean_cards = [unicodedata.normalize('NFKD', line).encode("ascii", 'ignore').decode() for line in clean_cards]
clean_cards[0:10]
# Out:
# ['PER ME SI VA NE LA CITTA DOLENTE',
#  'PER ME SI VA NE L ETTERNO DOLORE',
#  'PER ME SI VA TRA LA PERDUTA GENTE',
#  'GIUSTIZIA MOSSE IL MIO ALTO FATTORE',
#  'FECEMI LA DIVINA PODESTATE',
#  'LA SOMMA SAPIENZA E L PRIMO AMORE',
#  'DINANZI A ME NON FUOR COSE CREATE',
#  'SE NON ETTERNE E IO ETTERNO DURO',
#  'LASCIATE OGNE SPERANZA VOI CH INTRATE',
#  'QUESTE PAROLE DI COLORE OSCURO']

# %% [markdown]
# The next step is to tokenize. The algorighm described above by Tasman may not seem especially efficient, but it does have the merit of being algorithmically simple: you consider every column where a word starts (the first column or any column preceded by a space (or no punches), then one column at a time, you look for cards where words end.

# %%
wordcards = [] # our new stack of cards with each word

# look for columns with a space (starting with -1, or before the first word)
for start_column in range(-1, 50):
    
    # keep track of cards we've used for this start column
    used_cards = {}
    
    # make a temporary stack of cards for words that start in this column
    start_cards = [card for card in clean_cards if start_column==-1 or (len(card)>start_column and card[start_column]==" ")]
    
    # now look at each column after the start column (skip the first letter)
    for end_column in range(start_column+1, 50):
        
        # look at each remaining card
        for card in start_cards:
            
            # if the end column is a space or if it's the last character in the line
            if card not in used_cards and len(card) >= end_column and (len(card)==end_column or card[end_column]==" "):
                
                # add it to our word cards and remove it from our temporary stack
                wordcards.append((card[start_column+1:end_column], card))
                used_cards[card]=True

wordcards[0:5]
# Out:
# [('C', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  ('E', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('E', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('E', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('E', 'E IO MAESTRO CHE E TANTO GREVE')]

# %%
len(wordcards)
# Out:
# 956

# %% [markdown]
# **GR**: Tasman talks about 943 cards, one per word, but try as I might I can't see how he gets to that number... Also, I'm not sure how to deal with diacritics, you?

# %% [markdown]
# ## Sorting
#
# *Having reached this point, it is a trifle to put the words into alphabetical order; the Sorter, proceeding backwards, from the last letter, sorts and groups gradually column by column, all the identical letters; in a few minutes the words are aligned and the card file, in alphabetical order, is already compiled.*

# %%
# we'll do this properly as per the description, but here's a simpler version
sorted(wordcards, key=lambda tup: tup[0])
# Out:
# [('A', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  ('A', 'A DIO SPIACENTI E A NEMICI SUI'),
#  ('A', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  ('A', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  ('A', 'DINANZI A ME NON FUOR COSE CREATE'),
#  ('A', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  ('A', 'ED ELLI A ME QUESTO MISERO MODO'),
#  ('A', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  ('A', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  ('A', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  ('A', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  ('A', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  ('A', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  ('A', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  ('A', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  ('A', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  ('A', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  ('A', 'A DIO SPIACENTI E A NEMICI SUI'),
#  ('A', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  ('A', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('A', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  ('ACCENNANDO', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  ('ACCENTI', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  ('ACCORTA', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  ('ACHERONTE', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  ('AD', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  ('AD', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  ('ADAGIA', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  ('ADAMO', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  ('AERE', 'RISONAVAN PER L AERE SANZA STELLE'),
#  ('AGGIRA', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  ('AL', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  ('AL', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  ('AL', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  ('AL', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  ('AL', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('ALCUN', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  ('ALCUNA', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  ('ALLOR', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  ('ALTE', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('ALTI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  ('ALTO', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  ('ALTRA', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  ('ALTRA', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('ALTRA', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  ('ALTRA', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  ('ALTRI', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  ('AMORE', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  ('ANCHE', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  ('ANCOR', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  ('ANGELI', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  ('ANIMA', 'E TU CHE SE COSTI ANIMA VIVA'),
#  ('ANIMA', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  ('ANIME', 'TEGNON L ANIME TRISTE DI COLORO'),
#  ('ANIME', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  ('ANIME', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  ('ANTICO', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  ('APPRESSO', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('ATTENDE', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  ('AUGEL', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  ('AUNA', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  ('AURA', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  ('AUTUNNO', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  ('AVANTI', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  ('AVEA', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('AVEA', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  ('AVEREI', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  ('AVESSE', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  ('AVREBBER', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  ('BAGNA', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  ('BALENO', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  ('BASSA', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  ('BASSI', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  ('BATTE', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  ('BELLI', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  ('BEN', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  ('BEN', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  ('BESTEMMIAVANO', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  ('BIANCO', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  ('BRAGIA', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  ('BREVE', 'RISPUOSE DICEROLTI MOLTO BREVE'),
#  ('BRUNA', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  ('BUIA', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  ('BUONA', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  ('C', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  ('CACCIANLI', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  ('CADDI', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  ('CALDO', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  ('CAMPAGNA', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  ('CANGIAR', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  ('CARON', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  ('CARON', 'E PERO SE CARON DI TE SI LAGNA'),
#  ('CARON', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  ('CATTIVI', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  ('CATTIVO', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  ('CENNI', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  ('CERTO', 'INCONTANENTE INTESI E CERTO FUI'),
#  ('CH', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  ('CH', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  ('CH', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  ('CH', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('CH', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  ('CH', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  ('CH', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('CH', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  ('CH', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  ('CH', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  ('CH', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  ('CH', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  ('CH', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  ('CH', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  ('CH', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  ('CHE', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  ('CHE', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  ('CHE', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  ('CHE', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  ('CHE', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  ('CHE', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  ('CHE', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  ('CHE', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  ('CHE', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  ('CHE', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  ('CHE', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  ('CHE', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  ('CHE', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('CHE', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  ('CHE', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  ('CHE', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  ('CHE', 'E TU CHE SE COSTI ANIMA VIVA'),
#  ('CHE', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('CHE', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  ('CHE', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  ('CHE', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  ('CHE', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  ('CHE', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  ('CHE', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('CHE', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  ('CHE', 'E IO MAESTRO CHE E TANTO GREVE'),
#  ('CHE', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  ('CHE', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  ('CHE', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  ('CHE', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  ('CHE', 'PARTITI DA COTESTI CHE SON MORTI'),
#  ('CHE', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  ('CHE', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  ('CHE', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  ('CHE', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('CIASCUN', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  ('CIASCUN', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  ('CIECA', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  ('CIEL', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  ('CIELO', 'NON ISPERATE MAI VEDER LO CIELO'),
#  ('CINTA', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('CIO', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  ('CITTA', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  ('COL', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  ('COLA', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  ('COLORE', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  ('COLORE', 'QUESTE PAROLE DI COLORE OSCURO'),
#  ('COLORO', 'TEGNON L ANIME TRISTE DI COLORO'),
#  ('COLUI', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  ('COM', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  ('COME', 'COME LA RENA QUANDO TURBO SPIRA'),
#  ('COME', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  ('COME', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  ('COME', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  ('COME', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  ('COMINCIAR', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  ('CON', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  ('CON', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  ('CON', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  ('CON', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('CONCEDI', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  ('CONFORTAI', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  ('CONOBBI', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  ('CONTE', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  ('CONVEGNON', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  ('CONVIEN', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  ('CONVIEN', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  ('CONVIEN', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  ('CORO', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  ('CORREVA', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  ('CORTESE', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  ('COSE', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  ('COSE', 'DINANZI A ME NON FUOR COSE CREATE'),
#  ('COSE', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  ('COSI', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  ('COSI', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  ('COSTI', 'E TU CHE SE COSTI ANIMA VIVA'),
#  ('COSTUME', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  ('COTESTI', 'PARTITI DA COTESTI CHE SON MORTI'),
#  ('CREATE', 'DINANZI A ME NON FUOR COSE CREATE'),
#  ('CREDUTO', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  ('CRUCCIARE', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  ('CRUDE', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  ('CUI', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  ('D', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  ('D', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  ('D', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('D', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  ('D', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  ('D', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  ('D', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  ('D', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  ('D', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  ('D', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  ('D', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  ('D', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  ('DA', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  ('DA', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  ('DA', 'PARTITI DA COTESTI CHE SON MORTI'),
#  ('DA', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  ('DE', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  ('DE', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  ('DE', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('DE', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  ('DE', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  ('DEL', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  ('DENTI', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  ('DENTRO', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  ('DETTO', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('DI', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  ('DI', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  ('DI', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  ('DI', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  ('DI', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  ('DI', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  ('DI', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  ('DI', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  ('DI', 'QUESTE PAROLE DI COLORE OSCURO'),
#  ('DI', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  ('DI', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  ('DI', 'E PERO SE CARON DI TE SI LAGNA'),
#  ('DI', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  ('DI', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  ('DI', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  ('DI', 'TEGNON L ANIME TRISTE DI COLORO'),
#  ('DI', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  ('DI', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  ('DI', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('DI', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  ('DI', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  ('DI', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  ('DIBATTERO', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  ('DICEROLTI', 'RISPUOSE DICEROLTI MOLTO BREVE'),
#  ('DIEDE', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  ('DIEDI', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  ('DIETRO', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  ('DIMANDARE', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  ('DIMONIO', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  ('DINANZI', 'DINANZI A ME NON FUOR COSE CREATE'),
#  ('DIO', 'A DIO SPIACENTI E A NEMICI SUI'),
#  ('DIO', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  ('DIO', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  ('DIO', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  ('DIO', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  ('DIR', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  ('DIR', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  ('DISCERNO', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  ('DISCESE', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  ('DISFATTA', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  ('DISIO', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  ('DISSE', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  ('DISSE', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  ('DISSI', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  ('DISSI', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  ('DIVERSE', 'DIVERSE LINGUE ORRIBILI FAVELLE'),
#  ('DIVINA', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  ('DIVINA', 'FECEMI LA DIVINA PODESTATE'),
#  ('DOLENTE', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  ('DOLORE', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  ('DOLORE', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  ('DOLOROSE', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  ('DOVE', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  ('DUCA', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  ('DUOL', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('DURO', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  ('DURO', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('E', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('E', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('E', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('E', 'E IO MAESTRO CHE E TANTO GREVE'),
#  ('E', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  ('E', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  ('E', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  ('E', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  ('E', 'E TU CHE SE COSTI ANIMA VIVA'),
#  ('E', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  ('E', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  ('E', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  ('E', 'E PERO SE CARON DI TE SI LAGNA'),
#  ('E', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  ('E', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  ('E', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('E', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('E', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  ('E', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  ('E', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  ('E', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  ('E', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  ('E', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('E', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  ('E', 'A DIO SPIACENTI E A NEMICI SUI'),
#  ('E', 'E IO MAESTRO CHE E TANTO GREVE'),
#  ('E', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  ('E', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  ('E', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  ('E', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  ('E', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('E', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  ('E', 'INCONTANENTE INTESI E CERTO FUI'),
#  ('E', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  ('E', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  ('E', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  ('E', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('E', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  ('E', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  ('E', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  ('E', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  ('E', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('E', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('EBBI', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  ('ECCO', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  ('ED', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  ('ED', 'ED ELLI A ME QUESTO MISERO MODO'),
#  ('ED', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  ('ED', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  ('ELLE', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  ('ELLE', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('ELLI', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  ('ELLI', 'ED ELLI A ME QUESTO MISERO MODO'),
#  ('ELLI', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  ('ELLI', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  ('ERA', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  ('ERA', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  ('ERAN', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  ('ERAN', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  ('ERANO', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  ('ERROR', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('ESSER', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  ('ESSER', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  ('ETTERNE', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  ('ETTERNE', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  ('ETTERNO', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  ('ETTERNO', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  ('FA', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  ('FA', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  ('FACEVANO', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  ('FAMA', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  ('FASTIDIOSI', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  ('FATTORE', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  ('FAVELLE', 'DIVERSE LINGUE ORRIBILI FAVELLE'),
#  ('FECE', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  ('FECEMI', 'FECEMI LA DIVINA PODESTATE'),
#  ('FEDELI', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  ('FERMEREM', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  ('FIAMME', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  ('FIER', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  ('FIGLIUOL', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  ('FIN', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('FINITO', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  ('FIOCHE', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('FIOCO', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  ('FIUME', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  ('FIUME', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  ('FOGLIE', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  ('FORTE', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  ('FORTE', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  ('FORTE', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  ('FOSSE', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  ('FUI', 'INCONTANENTE INTESI E CERTO FUI'),
#  ('FUOR', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  ('FUOR', 'DINANZI A ME NON FUOR COSE CREATE'),
#  ('FUORO', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  ('FUR', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  ('FUR', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  ('FURON', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  ('GELO', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  ('GENT', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('GENTE', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  ('GENTE', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  ('GENTI', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  ('GENTI', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  ('GIRANDO', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  ('GITTANSI', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  ('GIUSTIZIA', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  ('GIUSTIZIA', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  ('GIUSTIZIA', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  ('GLORIA', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  ('GOTE', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  ('GRAN', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  ('GRAN', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  ('GRAVE', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  ('GREVE', 'E IO MAESTRO CHE E TANTO GREVE'),
#  ('GRIDANDO', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  ('GUAI', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  ('GUAI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  ('GUARDA', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  ('HANNO', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  ('HANNO', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  ('HO', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('I', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  ('I', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  ('I', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  ('I', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  ('I', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  ('I', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  ('I', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('I', 'CANGIAR COLORE E DIBATTERO I DENTI'),
#  ('I', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  ('IGNUDI', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  ('IL', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  ('IL', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  ('IL', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  ('IL', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  ('IL', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('IL', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  ('IL', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  ('IL', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  ('IN', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  ('IN', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  ('IN', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  ('INCONTANENTE', 'INCONTANENTE INTESI E CERTO FUI'),
#  ('INDEGNA', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  ('INFERNO', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  ('INFINO', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  ('INSIEME', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  ('INTELLETTO', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  ('INTESI', 'INCONTANENTE INTESI E CERTO FUI'),
#  ('INTRATE', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  ('IO', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('IO', 'E IO MAESTRO CHE E TANTO GREVE'),
#  ('IO', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  ('IO', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  ('IO', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  ('IO', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('IO', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  ('IO', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  ('IO', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  ('IO', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  ('IO', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  ('IO', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  ('IRA', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  ('IRA', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  ('ISPERATE', 'NON ISPERATE MAI VEDER LO CIELO'),
#  ('IVI', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  ('L', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('L', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('L', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  ('L', 'TEGNON L ANIME TRISTE DI COLORO'),
#  ('L', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  ('L', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  ('L', 'RISONAVAN PER L AERE SANZA STELLE'),
#  ('L', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  ('L', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  ('L', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('L', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('L', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  ('L', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  ('L', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  ('L', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  ('L', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  ('L', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  ('L', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  ('L', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('L', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('L', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('LA', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  ('LA', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  ('LA', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  ('LA', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  ('LA', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  ('LA', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  ('LA', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  ('LA', 'COME LA RENA QUANDO TURBO SPIRA'),
#  ('LA', 'FECEMI LA DIVINA PODESTATE'),
#  ('LA', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  ('LA', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  ('LA', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('LA', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  ('LA', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  ('LA', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  ('LA', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  ('LA', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  ('LA', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  ('LA', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  ('LA', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('LA', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  ('LA', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('LAGNA', 'E PERO SE CARON DI TE SI LAGNA'),
#  ('LAGRIMAI', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  ('LAGRIME', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  ('LAGRIMOSA', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  ('LAMENTAR', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  ('LANOSE', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  ('LASCIARE', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  ('LASCIATE', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  ('LASSA', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  ('LASSE', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  ('LE', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  ('LE', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  ('LE', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  ('LE', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  ('LE', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  ('LE', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  ('LE', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  ('LE', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  ('LE', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  ('LE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  ('LE', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  ('LEGNO', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  ('LEVAN', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  ('LI', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  ('LI', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  ('LI', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  ('LI', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  ('LI', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  ('LI', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  ('LI', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  ('LI', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  ('LI', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  ('LIETO', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  ('LIEVE', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  ('LINGUE', 'DIVERSE LINGUE ORRIBILI FAVELLE'),
#  ('LITO', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  ('LIVIDA', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  ('LO', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  ('LO', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  ('LO', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  ('LO', 'NON ISPERATE MAI VEDER LO CIELO'),
#  ('LO', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  ('LOCO', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('LOCO', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('LODO', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  ('LOR', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  ('LOR', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  ('LOR', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  ('LOR', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  ('LOR', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  ('LOR', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  ('LOR', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  ('LOR', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('LOR', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  ('LORO', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  ('LORO', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  ('LUCE', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  ('LUI', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  ('LUME', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  ('LUNGA', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  ('M', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('MA', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  ('MA', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  ('MA', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  ('MA', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  ('MAESTRO', 'E IO MAESTRO CHE E TANTO GREVE'),
#  ('MAESTRO', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  ('MAESTRO', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('MAESTRO', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  ('MAESTRO', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  ('MAI', 'NON ISPERATE MAI VEDER LO CIELO'),
#  ('MAI', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  ('MAI', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  ('MAL', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  ('MALVAGIA', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  ('MAN', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('MANO', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('ME', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  ('ME', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  ('ME', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  ('ME', 'DINANZI A ME NON FUOR COSE CREATE'),
#  ('ME', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  ('ME', 'ED ELLI A ME QUESTO MISERO MODO'),
#  ('ME', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  ('MEN', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  ('MENARVI', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  ('MENTE', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  ('MI', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  ('MI', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  ('MI', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  ('MI', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  ('MI', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  ('MI', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  ('MI', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  ('MI', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  ('MI', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  ('MIA', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('MIO', 'FIGLIUOL MIO DISSE L MAESTRO CORTESE'),
#  ('MIO', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  ('MIO', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  ('MISCHIATE', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  ('MISCHIATO', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  ('MISE', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  ('MISERICORDIA', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  ('MISERO', 'ED ELLI A ME QUESTO MISERO MODO'),
#  ('MODO', 'ED ELLI A ME QUESTO MISERO MODO'),
#  ('MOLTO', 'RISPUOSE DICEROLTI MOLTO BREVE'),
#  ('MOLTO', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  ('MONDO', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  ('MORTA', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  ('MORTE', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  ('MORTE', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  ('MORTI', 'PARTITI DA COTESTI CHE SON MORTI'),
#  ('MOSCONI', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  ('MOSSE', 'GIUSTIZIA MOSSE IL MIO ALTO FATTORE'),
#  ('MUOION', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  ('N', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  ('N', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  ('NASCIMENTI', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  ('NAVE', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  ('NE', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  ('NE', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  ('NE', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  ('NE', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  ('NE', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  ('NE', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  ('NE', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  ('NEL', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('NEMICI', 'A DIO SPIACENTI E A NEMICI SUI'),
#  ('NFAMIA', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  ('NO', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  ('NOCCHIER', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  ('NOI', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('NOI', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  ('NOI', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  ('NON', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  ('NON', 'NON ISPERATE MAI VEDER LO CIELO'),
#  ('NON', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  ('NON', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  ('NON', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  ('NON', 'DINANZI A ME NON FUOR COSE CREATE'),
#  ('NON', 'DI GENTE CH I NON AVEREI CREDUTO'),
#  ('NON', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  ('NON', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  ('NON', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  ('NON', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  ('NON', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  ('NON', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  ('NON', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  ('NON', 'FAMA DI LORO IL MONDO ESSER NON LASSA'),
#  ('NON', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  ('NOSTRI', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  ('NSEGNA', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  ('NTESER', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  ('NTORNO', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  ('NUDE', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  ('NUOVA', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  ('NVIDIOSI', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  ('OCCHI', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  ('OCCHI', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  ('OCCHI', 'CARON DIMONIO CON OCCHI DI BRAGIA'),
#  ('ODO', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  ('OGNE', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  ('OGNE', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  ('OGNE', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  ('OGNE', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  ('OGNE', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  ('OGNE', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  ('OLTRE', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  ('OMAI', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  ('OMBRA', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  ('OND', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  ('ONDA', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  ('OR', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  ('ORRIBILI', 'DIVERSE LINGUE ORRIBILI FAVELLE'),
#  ('OSCURO', 'QUESTE PAROLE DI COLORE OSCURO'),
#  ('OV', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('PAESE', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  ('PALUDE', 'AL NOCCHIER DE LA LIVIDA PALUDE'),
#  ('PAR', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('PAREA', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  ('PARENTI', 'BESTEMMIAVANO DIO E LOR PARENTI'),
#  ('PARER', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  ('PARLAR', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  ('PAROLE', 'PAROLE DI DOLORE ACCENTI D IRA'),
#  ('PAROLE', 'QUESTE PAROLE DI COLORE OSCURO'),
#  ('PAROLE', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  ('PARTITI', 'PARTITI DA COTESTI CHE SON MORTI'),
#  ('PARTIVA', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  ('PASSA', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  ('PASSA', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  ('PASSARE', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  ('PASSI', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  ('PELO', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  ('PER', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  ('PER', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  ('PER', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  ('PER', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('PER', 'PER CH IO AL COMINCIAR NE LAGRIMAI'),
#  ('PER', 'PER CH IO DISSI MAESTRO OR MI CONCEDI'),
#  ('PER', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  ('PER', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  ('PER', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  ('PER', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  ('PER', 'RISONAVAN PER L AERE SANZA STELLE'),
#  ('PER', 'COM IO DISCERNO PER LO FIOCO LUME'),
#  ('PER', 'CACCIANLI I CIEL PER NON ESSER MEN BELLI'),
#  ('PER', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  ('PER', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  ('PER', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  ('PER', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  ('PER', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  ('PER', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  ('PER', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  ('PERDUTA', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  ('PERDUTO', 'C HANNO PERDUTO IL BEN DE L INTELLETTO'),
#  ('PERO', 'E PERO SE CARON DI TE SI LAGNA'),
#  ('PERSONA', 'ED ELLI A ME COME PERSONA ACCORTA'),
#  ('PIAGGIA', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  ('PIANGENDO', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  ('PIANTI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  ('PIEDI', 'CHE MISCHIATO DI LAGRIME A LOR PIEDI'),
#  ('PIGLIA', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  ('PIU', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  ('PIU', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  ('PODESTATE', 'FECEMI LA DIVINA PODESTATE'),
#  ('POI', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  ('POI', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('POI', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  ('POI', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  ('PORTA', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  ('PORTI', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  ('PORTI', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  ('POSA', 'CHE D OGNE POSA MI PAREA INDEGNA'),
#  ('POSCIA', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  ('PRAVE', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  ('PRIMO', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  ('PROFONDO', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  ('PRONTE', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  ('PRONTI', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  ('PUOI', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  ('PUOSE', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('PUOTE', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  ('QUA', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  ('QUAL', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  ('QUAL', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  ('QUAL', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  ('QUALI', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  ('QUALUNQUE', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  ('QUANDO', 'QUANDO NOI FERMEREM LI NOSTRI PASSI'),
#  ('QUANDO', 'COME LA RENA QUANDO TURBO SPIRA'),
#  ('QUANTE', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  ('QUEL', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  ('QUEL', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  ('QUEL', 'DISSI MAESTRO CHE E QUEL CH I ODO'),
#  ('QUELL', 'MA QUELL ANIME CH ERAN LASSE E NUDE'),
#  ('QUELL', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  ('QUELLI', 'QUELLI CHE MUOION NE L IRA DI DIO'),
#  ('QUESTA', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  ('QUESTE', 'QUESTE PAROLE DI COLORE OSCURO'),
#  ('QUESTI', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  ('QUESTI', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  ('QUESTO', 'FINITO QUESTO LA BUIA CAMPAGNA'),
#  ('QUESTO', 'ED ELLI A ME QUESTO MISERO MODO'),
#  ('QUETE', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  ('QUI', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  ('QUI', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  ('QUI', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  ('QUI', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  ('QUINCI', 'QUINCI FUOR QUETE LE LANOSE GOTE'),
#  ('QUINCI', 'QUINCI NON PASSA MAI ANIMA BUONA'),
#  ('QUIVI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  ('RACCOGLIE', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  ('RAGIONIAM', 'NON RAGIONIAM DI LOR MA GUARDA E PASSA'),
#  ('RAMO', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('RATTA', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  ('RATTO', 'RATTO CHE NTESER LE PAROLE CRUDE'),
#  ('REI', 'CH ALCUNA GLORIA I REI AVREBBER D ELLI'),
#  ('REMO', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  ('RENA', 'COME LA RENA QUANDO TURBO SPIRA'),
#  ('RIBELLI', 'DE LI ANGELI CHE NON FURON RIBELLI'),
#  ('RICEVE', 'NE LO PROFONDO INFERNO LI RICEVE'),
#  ('RICHIAMO', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  ('RICOLTO', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  ('RICONOSCIUTO', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  ('RIFIUTO', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  ('RIGAVAN', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  ('RIGUARDAI', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  ('RIGUARDAR', 'E POI CH A RIGUARDAR OLTRE MI DIEDI'),
#  ('RIO', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  ('RISONAVAN', 'RISONAVAN PER L AERE SANZA STELLE'),
#  ('RISPUOSE', 'RISPUOSE DICEROLTI MOLTO BREVE'),
#  ('RITRASSER', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  ('RIVA', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  ('RIVA', 'FORTE PIANGENDO A LA RIVA MALVAGIA'),
#  ('RIVA', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  ('RIVIERA', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  ('ROTE', 'CHE NTORNO A LI OCCHI AVEA DI FIAMME ROTE'),
#  ('S', 'BATTE COL REMO QUALUNQUE S ADAGIA'),
#  ('S', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  ('S', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  ('SANGUE', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  ('SANZA', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  ('SANZA', 'RISONAVAN PER L AERE SANZA STELLE'),
#  ('SANZA', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  ('SANZA', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  ('SAPERE', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  ('SAPIENZA', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  ('SAPPIA', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  ('SCHIERA', 'ANCHE DI QUA NUOVA SCHIERA S AUNA'),
#  ('SCIAURATI', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  ('SCRITTE', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  ('SDEGNA', 'MISERICORDIA E GIUSTIZIA LI SDEGNA'),
#  ('SE', 'SE NON ETTERNE E IO ETTERNO DURO'),
#  ('SE', 'E PERO SE CARON DI TE SI LAGNA'),
#  ('SE', 'E TU CHE SE COSTI ANIMA VIVA'),
#  ('SE', 'NE FUR FEDELI A DIO MA PER SE FUORO'),
#  ('SEGRETE', 'MI MISE DENTRO A LE SEGRETE COSE'),
#  ('SEME', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  ('SEME', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('SEMENZA', 'DI LOR SEMENZA E DI LOR NASCIMENTI'),
#  ('SEMPRE', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  ('SEN', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  ('SENSO', 'PER CH IO MAESTRO IL SENSO LOR M E DURO'),
#  ('SENTIMENTO', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  ('SETTA', 'CHE QUESTA ERA LA SETTA D I CATTIVI'),
#  ('SI', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  ('SI', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  ('SI', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  ('SI', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  ('SI', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  ('SI', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  ('SI', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  ('SI', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  ('SI', 'COME D AUTUNNO SI LEVAN LE FOGLIE'),
#  ('SI', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  ('SI', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  ('SI', 'VUOLSI COSI COLA DOVE SI PUOTE'),
#  ('SI', 'E PERO SE CARON DI TE SI LAGNA'),
#  ('SI', 'A LOR CHE LAMENTAR LI FA SI FORTE'),
#  ('SI', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  ('SI', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('SIA', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  ('SIAM', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('SIEN', 'E AVANTI CHE SIEN DI LA DISCESE'),
#  ('SIMILEMENTE', 'SIMILEMENTE IL MAL SEME D ADAMO'),
#  ('SOMMA', 'LA SOMMA SAPIENZA E L PRIMO AMORE'),
#  ('SOMMO', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  ('SON', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  ('SON', 'PARTITI DA COTESTI CHE SON MORTI'),
#  ('SONNO', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  ('SONO', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  ('SONO', 'MISCHIATE SONO A QUEL CATTIVO CORO'),
#  ('SONO', 'CH I SAPPIA QUALI SONO E QUAL COSTUME'),
#  ('SORTE', 'CHE NVIDIOSI SON D OGNE ALTRA SORTE'),
#  ('SOSPETTO', 'QUI SI CONVIEN LASCIARE OGNE SOSPETTO'),
#  ('SOSPIRI', 'QUIVI SOSPIRI PIANTI E ALTI GUAI'),
#  ('SPAVENTO', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  ('SPERANZA', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  ('SPERANZA', 'QUESTI NON HANNO SPERANZA DI MORTE'),
#  ('SPEZIE', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('SPIACENTI', 'A DIO SPIACENTI E A NEMICI SUI'),
#  ('SPIRA', 'COME LA RENA QUANDO TURBO SPIRA'),
#  ('SPOGLIE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  ('SPRONA', 'CHE LA DIVINA GIUSTIZIA LI SPRONA'),
#  ('STELLE', 'RISONAVAN PER L AERE SANZA STELLE'),
#  ('STIMOLATI', 'ERANO IGNUDI E STIMOLATI MOLTO'),
#  ('SU', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  ('SU', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  ('SUA', 'E POI CHE LA SUA MANO A LA MIA PUOSE'),
#  ('SUDORE', 'LA MENTE DI SUDORE ANCOR MI BAGNA'),
#  ('SUE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  ('SUI', 'A DIO SPIACENTI E A NEMICI SUI'),
#  ('SUO', 'PER CENNI COME AUGEL PER SUO RICHIAMO'),
#  ('SUO', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  ('SUON', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('SUONA', 'BEN PUOI SAPERE OMAI CHE L SUO DIR SUONA'),
#  ('T', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('TANTA', 'CHE MORTE TANTA N AVESSE DISFATTA'),
#  ('TANTO', 'E IO MAESTRO CHE E TANTO GREVE'),
#  ('TANTO', 'CHE GIRANDO CORREVA TANTO RATTA'),
#  ('TANTO', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  ('TE', 'E PERO SE CARON DI TE SI LAGNA'),
#  ('TEGNON', 'TEGNON L ANIME TRISTE DI COLORO'),
#  ('TEMA', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  ('TEME', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  ('TEMENDO', 'TEMENDO NO L MIO DIR LI FOSSE GRAVE'),
#  ('TEMPO', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  ('TEMPO', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('TENEBRE', 'NE LE TENEBRE ETTERNE IN CALDO E N GELO'),
#  ('TERRA', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  ('TERRA', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  ('TESTA', 'E IO CH AVEA D ERROR LA TESTA CINTA'),
#  ('TI', 'ED ELLI A ME LE COSE TI FIER CONTE'),
#  ('TI', 'E L DUCA LUI CARON NON TI CRUCCIARE'),
#  ('TI', 'PIU LIEVE LEGNO CONVIEN CHE TI PORTI'),
#  ('TINTA', 'SEMPRE IN QUELL AURA SANZA TEMPO TINTA'),
#  ('TRA', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  ('TRAPASSAR', 'LE FA DI TRAPASSAR PARER SI PRONTE'),
#  ('TRAPASSAR', 'E PRONTI SONO A TRAPASSAR LO RIO'),
#  ('TRASSI', 'INFINO AL FIUME DEL PARLAR MI TRASSI'),
#  ('TRATTA', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  ('TREMO', 'TREMO SI FORTE CHE DE LO SPAVENTO'),
#  ('TRISTA', 'SU LA TRISTA RIVIERA D ACHERONTE'),
#  ('TRISTE', 'TEGNON L ANIME TRISTE DI COLORO'),
#  ('TU', 'E TU CHE SE COSTI ANIMA VIVA'),
#  ('TU', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  ('TUMULTO', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  ('TURBO', 'COME LA RENA QUANDO TURBO SPIRA'),
#  ('TUTTE', 'LORO ACCENNANDO TUTTE LE RACCOGLIE'),
#  ('TUTTE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  ('TUTTE', 'POI SI RITRASSER TUTTE QUANTE INSIEME'),
#  ('TUTTI', 'TUTTI CONVEGNON QUI D OGNE PAESE'),
#  ('UMANA', 'L UMANA SPEZIE E L LOCO E L TEMPO E L SEME'),
#  ('UN', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  ('UN', 'FACEVANO UN TUMULTO IL QUAL S AGGIRA'),
#  ('UN', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  ('UNA', 'L UNA APPRESSO DE L ALTRA FIN CHE L RAMO'),
#  ('UNA', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  ('UNA', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  ('UNA', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  ('UNA', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  ('UNA', 'GITTANSI DI QUEL LITO AD UNA AD UNA'),
#  ('UOM', 'E CADDI COME L UOM CUI SONNO PIGLIA'),
#  ('UOM', 'CH ATTENDE CIASCUN UOM CHE DIO NON TEME'),
#  ('V', 'POSCIA CH IO V EBBI ALCUN RICONOSCIUTO'),
#  ('VA', 'PER ME SI VA NE LA CITTA DOLENTE'),
#  ('VA', 'PER ME SI VA NE L ETTERNO DOLORE'),
#  ('VA', 'PER ME SI VA TRA LA PERDUTA GENTE'),
#  ('VANNO', 'COSI SEN VANNO SU PER L ONDA BRUNA'),
#  ('VECCHIO', 'UN VECCHIO BIANCO PER ANTICO PELO'),
#  ('VEDE', 'VEDE A LA TERRA TUTTE LE SUE SPOGLIE'),
#  ('VEDER', 'NON ISPERATE MAI VEDER LO CIELO'),
#  ('VEDRAI', 'CHE TU VEDRAI LE GENTI DOLOROSE'),
#  ('VEGNO', 'I VEGNO PER MENARVI A L ALTRA RIVA'),
#  ('VENIA', 'E DIETRO LE VENIA SI LUNGA TRATTA'),
#  ('VENIR', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  ('VENTO', 'LA TERRA LAGRIMOSA DIEDE VENTO'),
#  ('VENUTI', 'NOI SIAM VENUTI AL LOCO OV I T HO DETTO'),
#  ('VERGOGNOSI', 'ALLOR CON LI OCCHI VERGOGNOSI E BASSI'),
#  ('VERMI', 'DA FASTIDIOSI VERMI ERA RICOLTO'),
#  ('VERMIGLIA', 'CHE BALENO UNA LUCE VERMIGLIA'),
#  ('VERRAI', 'VERRAI A PIAGGIA NON QUI PER PASSARE'),
#  ('VERSO', 'ED ECCO VERSO NOI VENIR PER NAVE'),
#  ('VESPE', 'DA MOSCONI E DA VESPE CH ERAN IVI'),
#  ('VIA', 'DISSE PER ALTRA VIA PER ALTRI PORTI'),
#  ('VID', 'VID IO SCRITTE AL SOMMO D UNA PORTA'),
#  ('VIDE', 'MA POI CHE VIDE CH IO NON MI PARTIVA'),
#  ('VIDI', 'VIDI E CONOBBI L OMBRA DI COLUI'),
#  ('VIDI', 'VIDI GENTI A LA RIVA D UN GRAN FIUME'),
#  ('VIDI', 'E IO CHE RIGUARDAI VIDI UNA NSEGNA'),
#  ('VILTA', 'OGNE VILTA CONVIEN CHE QUI SIA MORTA'),
#  ('VILTADE', 'CHE FECE PER VILTADE IL GRAN RIFIUTO'),
#  ('VINSE', 'LA QUAL MI VINSE CIASCUN SENTIMENTO'),
#  ('VINTA', 'E CHE GENT E CHE PAR NEL DUOL SI VINTA'),
#  ('VISSER', 'CHE VISSER SANZA NFAMIA E SANZA LODO'),
#  ('VITA', 'E LA LOR CIECA VITA E TANTO BASSA'),
#  ('VIVA', 'E TU CHE SE COSTI ANIMA VIVA'),
#  ('VIVI', 'QUESTI SCIAURATI CHE MAI NON FUR VIVI'),
#  ('VOCI', 'VOCI ALTE E FIOCHE E SUON DI MAN CON ELLE'),
#  ('VOI', 'GRIDANDO GUAI A VOI ANIME PRAVE'),
#  ('VOI', 'LASCIATE OGNE SPERANZA VOI CH INTRATE'),
#  ('VOLTO', 'CON LIETO VOLTO OND IO MI CONFORTAI'),
#  ('VOLTO', 'ELLE RIGAVAN LOR DI SANGUE IL VOLTO'),
#  ('VOLVE', 'SI CHE LA TEMA SI VOLVE IN DISIO'),
#  ('VUOLE', 'CIO CHE SI VUOLE E PIU NON DIMANDARE'),
#  ('VUOLSI', 'VUOLSI COSI COLA DOVE SI PUOTE')]

# %% [markdown]
# ## Lemmatization
#
# *The philologist, however, must group or sort further on what the machine has not been able to «feel»; thus have, had are different forms of the same verb; thus, in Italian, andiamocene, diamogliene are several words joined into one, and for the Latin mortuus est is a single word form which means died, but could also mean the dead man is and then they would be two items; and so on for the whole wide range of homonyms.*
#
# ## Output
#
# *When the order has thus been properly modified and attains its final form, the cards are ready to be process in the Alphanumerical Accounting Machine, or Tabulator.
# The tabulator retranscribes on a sheet of paper, in letters and numbers— no longer in holes— line after line, the contents represented by the holes in the cards, at the rate of 4,800 cards per hour; and this is a page of the concordance or index in its final arrangement.*
#
# ## Headings
#
# *The concordance which I am presenting as an example is precisely an off-set reproduction of tabulated sheets turned out by the accounting machine. The tabulator's performance is extremely useful when, to use, the current technical phrase, it is running in tab. When another machine called the Summary Punch is connected to the accounting machine running in tab, while the latter is turning out the long tabulated list of different words, the former, electrically controlled by the accounting machine, simultanteously punches a new card for each of these words, thus providing ready headings to be placed before the single groups of lines or quotations. If necessary, these can be inserted in their proper place among all the others automatically by the collator.
#
# ## Phrases
#
# *This Collator which searches simultaneously two separate groups of cards at the rate of 20,000 per hour, and can insert, substitute and change cards from one with the cards from the other group, also offers some initial solutions to the problem of finding phrases or compound expressions. Taking, for example the expression according to: the group of cards containing according and that containing to are processed in the machine; on the basis of the identical quotation, the machine will extract all those cards on which both appear. It is true that they may be separated by other words, but one thing is certain, namely that all the cards bearing according to will be among those extracted; the eye and the hand must do the rest. It is still easier to obtain the same result when a card bearing the phrase sought for can be used as a pilot-card.*

# %% [markdown]
# ---
#
# CC-BY Stéfan Sinclair &amp; Geoffrey Rockwell
#
# Last updated September 14, 2016.
